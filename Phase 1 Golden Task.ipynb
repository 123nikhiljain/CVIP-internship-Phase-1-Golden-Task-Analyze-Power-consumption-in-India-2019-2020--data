# %% [markdown]
# # Phase 1 Golden Task

# %% [markdown]
# # Analyze Power consumption in India(2019-2020)

# %%
# Importing pandas library for data manipulation
import pandas as pd

# Importing matplotlib.pyplot for data visualization
import matplotlib.pyplot as plt

# Importing seaborn for statistical data visualization
import seaborn as sns

# %%
def power_consumption_2019(df1):
    # Calculate and print total power consumption during the year 2019
    Power_consumption = df1.sum(axis=0).sort_values(ascending=False)
    print("Total power consumed during the year 2019:")
    print(Power_consumption)
    print("\n")

    # Create a DataFrame for annual consumption and plot a bar chart
    Power_consumption = df1.sum(axis=0).sort_values(ascending=False).reset_index().rename(columns={"index": "state", 0: "Annual consumption 2019"})
    state_code = ['MH', 'GJ', 'UP', 'TN', 'RJ', 'MP', 'KA', 'TG', 'AP','WB', 'PH', 'HR', 'CT','BR', 'DL', 'OR', 'KL', 'J&K', 'UK', 'HP', 'AS', 'JH', 'DNH', 'GA', 'PY', 'ML', 'TR','CH', 'MN', 'NL', 'AR', 'MZ', 'SK']
    Power_consumption.state = state_code
    plt.figure(figsize=(30, 30))
    sns.barplot(x="state", y="Annual consumption 2019", data=Power_consumption)
    plt.title("Power consumption in India during 2019")
    plt.show()

    # Calculate and print the maximum power consumed by states in a day in 2019
    max_power = df1.max(axis=0).sort_values(ascending=False)
    print("Maximum power consumed by the states in a day in 2019:")
    print(max_power)
    print("\n")

    # Calculate and print the minimum power consumed by states in a day in 2019
    min_power = df1.min(axis=0).sort_values(ascending=False)
    print("Minimum power consumed by the states in a day in 2019:")
    print(min_power)
    print("\n")

# %%
def power_consumption_2020(df2):
    # Calculate and print total power consumption during the year 2020
    Power_consumption = df2.sum(axis=0).sort_values(ascending=False)
    print("Total power consumed during the year 2020:")
    print(Power_consumption)
    print("\n")

    # Create a DataFrame for annual consumption and plot a bar chart
    Power_consumption = df2.sum(axis=0).sort_values(ascending=False).reset_index().rename(columns={"index": "state", 0: "Annual consumption 2020"})
    state_code = ['MH', 'GJ', 'UP', 'TN', 'RJ', 'MP', 'KA', 'TG', 'AP', 'PH', 'HR','WB', 'DL','CT', 'BR', 'OR', 'KL', 'J&K', 'UK', 'HP', 'AS', 'JH', 'DNH', 'GA', 'PY', 'ML', 'CH', 'TR', 'MN', 'NL', 'AR', 'MZ', 'SK']
    Power_consumption.state = state_code
    plt.figure(figsize=(30, 30))
    sns.barplot(x="state", y="Annual consumption 2020", data=Power_consumption)
    plt.title("Power consumption in India during 2020")
    plt.show()

    # Calculate and print the maximum power consumed by states in a day in 2020
    max_power = df2.max(axis=0).sort_values(ascending=False)
    print("Maximum power consumed by the states in a day in 2020:")
    print(max_power)
    print("\n")

    # Calculate and print the minimum power consumed by states in a day in 2020
    min_power = df2.min(axis=0).sort_values(ascending=False)
    print("Minimum power consumed by the states in a day in 2020:")
    print(min_power)
    print("\n")

# %%
def tot_power_consumption(df):
    # Calculate and print the total power consumption during 2019 and 2020
    Total_consumption = df.sum(axis=0).sort_values(ascending=False)
    print("Total power consumption during 2019 and 2020:")
    print(Total_consumption)
    print("\n")

    # Create a DataFrame for total consumption and plot a bar chart
    Total_consumption = df.sum(axis=0).sort_values(ascending=False).reset_index().rename(columns={"index": "state", 0: "Total consumption"})
    state_code = ['MH', 'GJ', 'UP', 'TN', 'RJ', 'MP', 'KA', 'TG', 'AP', 'PH', 'WB', 'HR', 'CT', 'DL', 'BR', 'OR', 'KL', 'J&K', 'UK', 'HP', 'AS', 'JH', 'DNH', 'GA', 'PY', 'ML', 'CH', 'TR', 'MN', 'NL', 'AR', 'MZ', 'SK']
    Total_consumption.state = state_code
    plt.figure(figsize=(30, 30))
    sns.barplot(x="state", y="Total consumption", data=Total_consumption)
    plt.title("Power consumption in India during 2019 and 2020")
    plt.show()

# %%
def lockdown(df3, df4):
    # Calculate total power consumption before and after the lockdown
    before = df3.sum(axis=0)
    after = df4.sum(axis=0)

    # Perform comparison and create a DataFrame
    df5 = before.compare(after)
    print(df5)

    # Plot the differences using a bar chart
    df5.plot.bar()
    plt.title("Power consumption before and after Lockdown")
    plt.show()

# %%
# Read the dataset
df = pd.read_csv("dataset_tk.csv", parse_dates=True, index_col="Unnamed: 0")

# Slice the DataFrame for the year 2019
df1 = df[:359]
print("The data for the power consumed during the year 2019:")
print(df1)
print("\n")
df1.isnull().sum()

# Calculate and print power consumption for 2019
pc1 = power_consumption_2019(df1)

# Slice the DataFrame for the year 2020
df2 = df[359:]
print("The data for the power consumed during the year 2020:")
print(df2)
print("\n")
df2.isnull().sum()

# Calculate and print power consumption for 2020
pc2 = power_consumption_2020(df2)

# Print power consumption for both years
print("The power consumed during the year 2019 and 2020:")
print(df)
print("\n")
df.isnull().sum()

# Calculate and print total power consumption for both years
pc3 = tot_power_consumption(df)

# Slice the DataFrame for normal days and lockdown
df3 = df[57:146]
df4 = df[405:468]
print("The power consumed during normal days and lockdown:")
pc4 = lockdown()
# Out:
# The data for the power consumed during the year 2019:
#             Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand    HP   J&K  \
# 2019-02-01   119.9    130.3      234.1   85.8  313.9         40.7  30.0  52.5
# 2019-03-01   121.9    133.5      240.2   85.5  311.8         39.3  30.1  54.1
# 2019-04-01   118.8    128.2      239.8   83.5  320.7         38.1  30.1  53.2
# 2019-05-01   121.0    127.5      239.1   79.2  299.0         39.2  30.2  51.5
# 2019-06-01   121.4    132.6      240.4   76.6  286.8         39.2  31.0  53.2
# ...            ...      ...        ...    ...    ...          ...   ...   ...
# 2019-12-27   103.7    110.4      211.4   63.8  229.9         33.4  29.3  44.2
# 2019-12-28    97.2    101.7      212.7   62.0  234.2         32.7  27.6  47.7
# 2019-12-29   237.2    214.1      232.7  128.5  421.3         42.0  29.9  40.0
# 2019-12-30   251.9    220.1      246.5  126.9  437.4         43.3  31.6  42.8
# 2019-12-31   255.0    223.2      253.5  134.9  424.0         44.3  31.6  42.9
#
#             Chandigarh  Chhattisgarh  ...  Odisha  West Bengal  Sikkim  \
# 2019-02-01         5.0          78.7  ...    70.2        108.2     2.0
# 2019-03-01         4.9          78.8  ...    67.9        110.2     1.9
# 2019-04-01         4.8          74.8  ...    66.3        106.8     1.7
# 2019-05-01         4.3          69.0  ...    65.8        107.0     2.0
# 2019-06-01         4.3          68.1  ...    62.9        106.4     2.0
# ...                ...           ...  ...     ...          ...     ...
# 2019-12-27         3.8          75.8  ...    79.8        112.0     1.7
# 2019-12-28         3.4          74.2  ...    75.8        108.3     1.6
# 2019-12-29         6.4          78.9  ...    95.7        166.9     1.0
# 2019-12-30         6.4          83.8  ...    99.2        173.9     1.1
# 2019-12-31         6.7          86.5  ...    98.5        174.3     1.0
#
#             Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  \
# 2019-02-01                2.1   21.7      2.7        6.1      1.9       2.2
# 2019-03-01                2.2   23.4      2.4        6.5      1.8       2.2
# 2019-04-01                2.2   21.7      2.4        6.3      1.7       2.2
# 2019-05-01                2.2   22.5      2.7        5.7      1.8       2.3
# 2019-06-01                2.2   21.7      2.7        6.2      1.9       2.3
# ...                       ...    ...      ...        ...      ...       ...
# 2019-12-27                2.0   20.1      2.6        5.8      2.0       2.1
# 2019-12-28                2.0   19.7      2.5        6.0      1.7       2.1
# 2019-12-29                2.0   34.2      2.4        5.3      1.7       2.1
# 2019-12-30                2.3   35.0      2.4        5.6      1.8       2.1
# 2019-12-31                2.2   34.7      2.5        5.7      1.7       2.2
#
#             Tripura
# 2019-02-01      3.4
# 2019-03-01      3.6
# 2019-04-01      3.5
# 2019-05-01      3.5
# 2019-06-01      3.3
# ...             ...
# 2019-12-27      3.4
# 2019-12-28      3.4
# 2019-12-29      4.9
# 2019-12-30      4.9
# 2019-12-31      5.0
#
# [359 rows x 33 columns]
#
#
# Total power consumed during the year 2019:
# Maharashtra          154916.7
# Gujarat              115357.4
# UP                   112689.9
# Tamil Nadu           106720.2
# Rajasthan             78138.8
# MP                    74974.6
# Karnataka             73076.9
# Telangana             67449.6
# Andhra Pradesh        63097.0
# West Bengal           49868.7
# Punjab                49635.7
# Haryana               48995.0
# Chhattisgarh          30179.9
# Bihar                 30007.9
# Delhi                 29458.3
# Odisha                28966.6
# Kerala                25798.2
# J&K                   15915.3
# Uttarakhand           12898.6
# HP                     9490.8
# Assam                  8979.4
# Jharkhand              8605.5
# DNH                    5845.4
# Goa                    4006.5
# Pondy                  2653.3
# Meghalaya              2018.1
# Tripura                1482.5
# Chandigarh             1472.4
# Manipur                 894.6
# Nagaland                776.8
# Arunachal Pradesh       754.0
# Mizoram                 614.3
# Sikkim                  466.4
# dtype: float64
# Maximum power consumed by the states in a day in 2019:
# Maharashtra          522.1
# UP                   469.0
# Gujarat              398.0
# Tamil Nadu           365.3
# Punjab               286.0
# Rajasthan            278.0
# Karnataka            273.3
# MP                   272.3
# Telangana            256.2
# Haryana              224.5
# Andhra Pradesh       205.1
# West Bengal          198.1
# Delhi                139.1
# Bihar                117.9
# Chhattisgarh         111.6
# Odisha               109.6
# Kerala                89.4
# J&K                   54.1
# Uttarakhand           53.2
# Assam                 38.0
# HP                    34.0
# Jharkhand             28.9
# DNH                   19.4
# Goa                   14.0
# Pondy                  9.7
# Chandigarh             6.8
# Meghalaya              6.8
# Tripura                6.6
# Manipur                3.2
# Sikkim                 2.8
# Nagaland               2.7
# Arunachal Pradesh      2.6
# Mizoram                2.2
# dtype: float64
#
#
# Minimum power consumed by the states in a day in 2019:
# Maharashtra          305.6
# Tamil Nadu           195.7
# Gujarat              192.3
# UP                   186.8
# Andhra Pradesh       142.2
# MP                   131.8
# Telangana            130.5
# Karnataka            121.0
# Rajasthan            105.8
# Haryana               64.8
# Punjab                56.1
# Kerala                55.0
# West Bengal           51.5
# Odisha                51.1
# Bihar                 43.5
# Delhi                 41.8
# Chhattisgarh          37.2
# J&K                   30.1
# Jharkhand             17.4
# Uttarakhand           16.8
# Assam                 14.3
# HP                    11.8
# Goa                    6.2
# Pondy                  4.0
# Meghalaya              3.4
# Tripura                2.4
# Chandigarh             2.2
# Manipur                1.5
# Nagaland               1.4
# DNH                    1.3
# Mizoram                1.3
# Arunachal Pradesh      1.1
# Sikkim                 0.5
# dtype: float64
#
#
# The data for the power consumed during the year 2020:
#             Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand    HP   J&K  \
# 2020-01-01   264.6    222.6      253.0  137.2  426.5         42.1  31.7  44.9
# 2020-02-01   259.7    224.4      247.4  132.6  393.0         42.9  30.6  41.3
# 2020-03-01   259.0    218.5      243.3  125.3  390.4         41.3  31.0  42.2
# 2020-04-01   248.8    200.9      237.1  116.2  393.1         38.5  28.7  39.7
# 2020-05-01    92.2     89.9      198.2   58.0  230.7         31.1  26.4  48.8
# ...            ...      ...        ...    ...    ...          ...   ...   ...
# 2020-01-12   130.8    126.0      220.4   77.3  322.8         36.5  25.4  45.4
# 2020-02-12   129.4    127.3      218.4   81.3  331.4         37.0  25.8  45.2
# 2020-03-12   132.1    129.7      205.6   85.6  336.7         37.8  26.2  45.2
# 2020-04-12   132.1    128.4      207.0   83.9  334.6         38.2  27.0  43.0
# 2020-05-12   120.4    111.2      201.4   83.6  287.3         35.2  24.3  42.6
#
#             Chandigarh  Chhattisgarh  ...  Odisha  West Bengal  Sikkim  \
# 2020-01-01         6.7          84.7  ...    96.5        162.9     1.0
# 2020-02-01         6.4          85.4  ...    98.9        160.9     0.9
# 2020-03-01         6.0          89.1  ...   100.1        166.7     1.0
# 2020-04-01         5.5          93.9  ...   102.8        164.9     0.7
# 2020-05-01         3.3          82.7  ...    73.1        100.0     1.3
# ...                ...           ...  ...     ...          ...     ...
# 2020-01-12         3.6         100.4  ...   105.7        172.6     1.4
# 2020-02-12         3.7         101.8  ...   112.3        174.4     1.5
# 2020-03-12         4.0         103.0  ...   113.0        169.8     1.4
# 2020-04-12         4.0         101.8  ...   111.6        145.5     1.2
# 2020-05-12         3.5         102.4  ...    95.1        110.4     1.2
#
#             Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  \
# 2020-01-01                2.1   34.1      2.4        5.5      1.8       2.2
# 2020-02-01                2.2   32.3      2.5        5.6      1.2       2.3
# 2020-03-01                2.2   31.5      2.4        5.7      1.8       2.5
# 2020-04-01                2.1   30.8      2.5        5.5      1.7       2.2
# 2020-05-01                2.2   22.6      2.6        5.7      1.6       2.1
# ...                       ...    ...      ...        ...      ...       ...
# 2020-01-12                2.1   20.4      2.1        5.4      1.8       2.0
# 2020-02-12                2.1   23.3      2.4        5.4      1.6       2.1
# 2020-03-12                2.1   21.7      2.3        5.4      1.5       2.0
# 2020-04-12                2.0   24.2      2.5        5.7      1.6       2.0
# 2020-05-12                2.1   20.3      2.5        5.8      1.6       2.1
#
#             Tripura
# 2020-01-01      4.8
# 2020-02-01      4.7
# 2020-03-01      4.8
# 2020-04-01      4.8
# 2020-05-01      3.9
# ...             ...
# 2020-01-12      2.4
# 2020-02-12      3.3
# 2020-03-12      3.6
# 2020-04-12      3.3
# 2020-05-12      3.3
#
# [144 rows x 33 columns]
#
#
# Total power consumed during the year 2020:
# Maharashtra          62163.1
# Gujarat              47131.5
# UP                   45270.4
# Tamil Nadu           44551.3
# Rajasthan            31738.2
# MP                   29791.8
# Karnataka            29588.8
# Telangana            26615.7
# Andhra Pradesh       25507.4
# Punjab               21360.5
# Haryana              20586.8
# West Bengal          19901.5
# Delhi                12482.2
# Chhattisgarh         12010.3
# Bihar                11821.3
# Odisha               11507.1
# Kerala               10514.6
# J&K                   6349.5
# Uttarakhand           5288.4
# HP                    3873.0
# Assam                 3575.5
# Jharkhand             3387.3
# DNH                   2419.2
# Goa                   1573.4
# Pondy                 1105.6
# Meghalaya              820.7
# Chandigarh             610.8
# Tripura                572.5
# Manipur                360.2
# Nagaland               310.9
# Arunachal Pradesh      306.9
# Mizoram                244.0
# Sikkim                 182.2
# dtype: float64
# Maximum power consumed by the states in a day in 2020:
# Maharashtra          504.1
# UP                   471.8
# Gujarat              400.8
# Tamil Nadu           365.4
# Punjab               300.0
# Rajasthan            275.2
# MP                   270.1
# Karnataka            259.2
# Telangana            254.1
# Haryana              237.2
# Andhra Pradesh       205.0
# West Bengal          198.5
# Delhi                147.1
# Bihar                121.4
# Odisha               113.0
# Chhattisgarh         103.0
# Kerala                88.6
# J&K                   54.2
# Uttarakhand           48.5
# Assam                 36.1
# HP                    31.8
# Jharkhand             28.9
# DNH                   19.5
# Goa                   13.7
# Pondy                  9.5
# Chandigarh             7.4
# Meghalaya              6.9
# Tripura                5.6
# Manipur                3.0
# Arunachal Pradesh      2.7
# Nagaland               2.6
# Sikkim                 2.1
# Mizoram                2.1
# dtype: float64
#
#
# Minimum power consumed by the states in a day in 2020:
# Maharashtra          367.1
# Gujarat              231.4
# Tamil Nadu           207.8
# UP                   205.3
# MP                   154.9
# Rajasthan            146.2
# Telangana            141.8
# Karnataka            136.3
# Andhra Pradesh       130.6
# West Bengal           91.1
# Punjab                69.5
# Haryana               69.1
# Chhattisgarh          65.6
# Odisha                60.4
# Kerala                59.8
# Bihar                 52.5
# Delhi                 44.3
# Uttarakhand           18.4
# J&K                   17.8
# Jharkhand             17.7
# Assam                 12.2
# HP                    11.9
# Goa                    6.6
# Pondy                  4.4
# Meghalaya              3.3
# Chandigarh             2.2
# Manipur                2.1
# DNH                    1.8
# Nagaland               1.8
# Tripura                1.4
# Arunachal Pradesh      1.3
# Mizoram                1.2
# Sikkim                 0.3
# dtype: float64
#
#
# The power consumed during the year 2019 and 2020:
#             Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand    HP   J&K  \
# 2019-02-01   119.9    130.3      234.1   85.8  313.9         40.7  30.0  52.5
# 2019-03-01   121.9    133.5      240.2   85.5  311.8         39.3  30.1  54.1
# 2019-04-01   118.8    128.2      239.8   83.5  320.7         38.1  30.1  53.2
# 2019-05-01   121.0    127.5      239.1   79.2  299.0         39.2  30.2  51.5
# 2019-06-01   121.4    132.6      240.4   76.6  286.8         39.2  31.0  53.2
# ...            ...      ...        ...    ...    ...          ...   ...   ...
# 2020-01-12   130.8    126.0      220.4   77.3  322.8         36.5  25.4  45.4
# 2020-02-12   129.4    127.3      218.4   81.3  331.4         37.0  25.8  45.2
# 2020-03-12   132.1    129.7      205.6   85.6  336.7         37.8  26.2  45.2
# 2020-04-12   132.1    128.4      207.0   83.9  334.6         38.2  27.0  43.0
# 2020-05-12   120.4    111.2      201.4   83.6  287.3         35.2  24.3  42.6
#
#             Chandigarh  Chhattisgarh  ...  Odisha  West Bengal  Sikkim  \
# 2019-02-01         5.0          78.7  ...    70.2        108.2     2.0
# 2019-03-01         4.9          78.8  ...    67.9        110.2     1.9
# 2019-04-01         4.8          74.8  ...    66.3        106.8     1.7
# 2019-05-01         4.3          69.0  ...    65.8        107.0     2.0
# 2019-06-01         4.3          68.1  ...    62.9        106.4     2.0
# ...                ...           ...  ...     ...          ...     ...
# 2020-01-12         3.6         100.4  ...   105.7        172.6     1.4
# 2020-02-12         3.7         101.8  ...   112.3        174.4     1.5
# 2020-03-12         4.0         103.0  ...   113.0        169.8     1.4
# 2020-04-12         4.0         101.8  ...   111.6        145.5     1.2
# 2020-05-12         3.5         102.4  ...    95.1        110.4     1.2
#
#             Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  \
# 2019-02-01                2.1   21.7      2.7        6.1      1.9       2.2
# 2019-03-01                2.2   23.4      2.4        6.5      1.8       2.2
# 2019-04-01                2.2   21.7      2.4        6.3      1.7       2.2
# 2019-05-01                2.2   22.5      2.7        5.7      1.8       2.3
# 2019-06-01                2.2   21.7      2.7        6.2      1.9       2.3
# ...                       ...    ...      ...        ...      ...       ...
# 2020-01-12                2.1   20.4      2.1        5.4      1.8       2.0
# 2020-02-12                2.1   23.3      2.4        5.4      1.6       2.1
# 2020-03-12                2.1   21.7      2.3        5.4      1.5       2.0
# 2020-04-12                2.0   24.2      2.5        5.7      1.6       2.0
# 2020-05-12                2.1   20.3      2.5        5.8      1.6       2.1
#
#             Tripura
# 2019-02-01      3.4
# 2019-03-01      3.6
# 2019-04-01      3.5
# 2019-05-01      3.5
# 2019-06-01      3.3
# ...             ...
# 2020-01-12      2.4
# 2020-02-12      3.3
# 2020-03-12      3.6
# 2020-04-12      3.3
# 2020-05-12      3.3
#
# [503 rows x 33 columns]
#
#
# Total power consumption during 2019 and 2020:
# Maharashtra          217079.8
# Gujarat              162488.9
# UP                   157960.3
# Tamil Nadu           151271.5
# Rajasthan            109877.0
# MP                   104766.4
# Karnataka            102665.7
# Telangana             94065.3
# Andhra Pradesh        88604.4
# Punjab                70996.2
# West Bengal           69770.2
# Haryana               69581.8
# Chhattisgarh          42190.2
# Delhi                 41940.5
# Bihar                 41829.2
# Odisha                40473.7
# Kerala                36312.8
# J&K                   22264.8
# Uttarakhand           18187.0
# HP                    13363.8
# Assam                 12554.9
# Jharkhand             11992.8
# DNH                    8264.6
# Goa                    5579.9
# Pondy                  3758.9
# Meghalaya              2838.8
# Chandigarh             2083.2
# Tripura                2055.0
# Manipur                1254.8
# Nagaland               1087.7
# Arunachal Pradesh      1060.9
# Mizoram                 858.3
# Sikkim                  648.6
# dtype: float64
# The power consumed during normal days and lockdown:
#                       self    other
# Punjab             13212.9   8260.6
# Haryana            12512.8   8294.9
# Rajasthan          19478.7  13956.1
# Delhi               7469.0   4966.4
# UP                 27550.3  18711.8
# Uttarakhand         3195.1   2214.3
# HP                  2369.9   1622.4
# J&K                 3931.2   2767.1
# Chandigarh           376.5    251.1
# Chhattisgarh        7675.4   4989.4
# Gujarat            28928.1  20001.0
# MP                 18586.9  13251.5
# Maharashtra        38772.0  26622.1
# Goa                  997.0    683.7
# DNH                 1486.4    952.2
# Andhra Pradesh     15745.9  11020.4
# Telangana          17338.4  11334.0
# Karnataka          18579.9  12864.6
# Kerala              6446.6   4514.6
# Tamil Nadu         26645.3  18909.1
# Pondy                662.3    460.4
# Bihar               7287.1   5004.8
# Jharkhand           2110.6   1483.9
# Odisha              7207.1   4764.2
# West Bengal        12162.5   8191.0
# Sikkim               120.1     87.2
# Arunachal Pradesh    188.1    130.8
# Assam               2236.8   1502.9
# Manipur              221.6    157.1
# Meghalaya            504.6    360.6
# Mizoram              152.2    106.2
# Nagaland             193.0    135.1
# Tripura              368.1    242.2
